# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from sklearn.datasets import make_blobs

n_groups=10
n_samples=600

# X, y = make_moons(n_samples=100, random_state=42)
X, y = make_blobs(n_samples=n_samples, centers=n_groups)
plt.scatter(X[:,0], X[:,1], s=100, c=y, alpha=0.5)
plt.show()

# %%
#подготовка тестового и тренировочного наборов данных
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2,random_state=1)

# %%
#подключение классификатора KNN
from sklearn.neighbors import KNeighborsClassifier
n_neighbors=10

model = KNeighborsClassifier(n_neighbors = n_neighbors)
model.fit(X_train,y_train)

score = model.score(X_test,y_test)
print("Аккуратность вычислений ",score)
# Out:
# Аккуратность вычислений  0.7916666666666666

# %%
# прогноз машиной тестовых данных и сравнение с актуальными
y_pred = model.predict(X_test)
y_pred == y_test

# %%
# !pip install --upgrade mlxtend

from mlxtend.plotting import plot_decision_regions

plot_decision_regions(X, y, clf=model)
plt.show()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# /usr/local/lib/python3.10/dist-packages/mlxtend/plotting/decision_regions.py:346: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(

# %%
c = model.predict([[2,  10]])
c
# Out:
# array([1])
